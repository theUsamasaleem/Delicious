# %%
# Python3 program to create target string, starting from
# random string using Genetic Algorithm

import random

# Number of individuals in each generation
POPULATION_SIZE = 100

# Valid genes
GENES = '''abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOP
QRSTUVWXYZ 1234567890, .-;:_!"#%&/()=?@${[]}'''

# Target string to be generated
TARGET = "I love DataScience"

class Individual(object):
	'''
	Class representing individual in population
	'''
	def __init__(self, chromosome):
		self.chromosome = chromosome
		self.fitness = self.cal_fitness()

	@classmethod
	def mutated_genes(self):
		'''
		create random genes for mutation
		'''
		global GENES
		gene = random.choice(GENES)
		return gene

	@classmethod
	def create_gnome(self):
		'''
		create chromosome or string of genes
		'''
		global TARGET
		gnome_len = len(TARGET)
		return [self.mutated_genes() for _ in range(gnome_len)]

	def mate(self, par2):
		'''
		Perform mating and produce new offspring
		'''

		# chromosome for offspring
		child_chromosome = []
		for gp1, gp2 in zip(self.chromosome, par2.chromosome):

			# random probability
			prob = random.random()

			# if prob is less than 0.45, insert gene
			# from parent 1
			if prob < 0.45:
				child_chromosome.append(gp1)
                

			# if prob is between 0.45 and 0.90, insert
			# gene from parent 2
			elif prob < 0.90:
				child_chromosome.append(gp2)
                

			# otherwise insert random gene(mutate),
			# for maintaining diversity
			else:
				child_chromosome.append(self.mutated_genes())

		# create new Individual(offspring) using
		# generated chromosome for offspring
		return Individual(child_chromosome)

	def cal_fitness(self):
		'''
		Calculate fitness score, it is the number of
		characters in string which differ from target
		string.
		'''
		global TARGET
		fitness = 0
		for gs, gt in zip(self.chromosome, TARGET):
			if gs != gt: fitness+= 1
		return fitness

# Driver code
def main():
	global POPULATION_SIZE

	#current generation
	generation = 1

	found = False
	population = []

	# create initial population
	for _ in range(POPULATION_SIZE):
				gnome = Individual.create_gnome()
				population.append(Individual(gnome))

	while not found:

		# sort the population in increasing order of fitness score
		population = sorted(population, key = lambda x:x.fitness)

		# if the individual having lowest fitness score ie.
		# 0 then we know that we have reached to the target
		# and break the loop
		if population[0].fitness <= 0:
			found = True
			break

		# Otherwise generate new offsprings for new generation
		new_generation = []

		# Perform Elitism, that mean 10% of fittest population
		# goes to the next generation
		s = int((10*POPULATION_SIZE)/100)
		new_generation.extend(population[:s])

		# From 50% of fittest population, Individuals
		# will mate to produce offspring
		s = int((90*POPULATION_SIZE)/100)
		for _ in range(s):
			parent1 = random.choice(population[:50])
			parent2 = random.choice(population[:50])
			child = parent1.mate(parent2)
			new_generation.append(child)

		population = new_generation

		print("Generation: {}\tString: {}\tFitness: {}".\
			format(generation,
			"".join(population[0].chromosome),
			population[0].fitness))

		generation += 1

	


if __name__ == '__main__':
	main()
# Out:
# Generation: 1	String: V;NtzUxVaNc clo}na	Fitness: 16
# Generation: 2	String: V;NtzUxVaNc clo}na	Fitness: 16
# Generation: 3	String: Ig[Kve18pT:J]:B;mr	Fitness: 15
# Generation: 4	String: Im[=ve18pT:J?:e;mr	Fitness: 14
# Generation: 5	String: Im[=ve18pT:J?:e;mr	Fitness: 14
# Generation: 6	String: Im[=ve18pT:J?:e;mr	Fitness: 14
# Generation: 7	String: Ig.KveYBaN
# }c"BnnE	Fitness: 12
# Generation: 8	String: IDz
# ve, a8}8clennC	Fitness: 11
# Generation: 9	String: IDz
# ve, a8}8clennC	Fitness: 11
# Generation: 10	String: IDz
# ve, a8}8clennC	Fitness: 11
# Generation: 11	String: I 3Kve/BaL
# }nqenNe	Fitness: 10
# Generation: 12	String: I 3Kve/BaL
# }nqenNe	Fitness: 10
# Generation: 13	String: I 3Kve/BaL
# }nqenNe	Fitness: 10
# Generation: 14	String: I 3Kve/BaL
# }nqenNe	Fitness: 10
# Generation: 15	String: I Ntve $ahhTc]ennN	Fitness: 9
# Generation: 16	String: I Ntve $ahhTc]ennN	Fitness: 9
# Generation: 17	String: I Ntve $ahhTc]ennN	Fitness: 9
# Generation: 18	String: I Ndve IakJ8cXenAe	Fitness: 8
# Generation: 19	String: I Ndve IakJ8cXenAe	Fitness: 8
# Generation: 20	String: I Ndve IakJ8cXenAe	Fitness: 8
# Generation: 21	String: I l:ve AakJ}cRenme	Fitness: 7
# Generation: 22	String: I l:ve AakJ}cRenme	Fitness: 7
# Generation: 23	String: I l:ve AakJ}cRenme	Fitness: 7
# Generation: 24	String: I l:ve AakJ}cRenme	Fitness: 7
# Generation: 25	String: I l:ve AakJ}cRenme	Fitness: 7
# Generation: 26	String: I l:ve AakJ}cRenme	Fitness: 7
# Generation: 27	String: I l:ve AakJ}cRenme	Fitness: 7
# Generation: 28	String: I l:ve AakJ}cRenme	Fitness: 7
# Generation: 29	String: I l:ve AakJ}cRenme	Fitness: 7
# Generation: 30	String: I lKve DaiH}c1en,e	Fitness: 6
# Generation: 31	String: I lKve DaiH}c1en,e	Fitness: 6
# Generation: 32	String: I lKve DaiH}c1en,e	Fitness: 6
# Generation: 33	String: I lKve DaiH}c1en,e	Fitness: 6
# Generation: 34	String: I lKve DaiH}c1en,e	Fitness: 6
# Generation: 35	String: I lKve DaiH}c1en,e	Fitness: 6
# Generation: 36	String: I lyve Da&};cien$e	Fitness: 5
# Generation: 37	String: I lyve Da&};cien$e	Fitness: 5
# Generation: 38	String: I lyve Da&};cien$e	Fitness: 5
# Generation: 39	String: I lyve Da&};cien$e	Fitness: 5
# Generation: 40	String: I lyve Da&};cien$e	Fitness: 5
# Generation: 41	String: I lyve Da&};cien$e	Fitness: 5
# Generation: 42	String: I lyve Da&};cien$e	Fitness: 5
# Generation: 43	String: I lyve Da&};cien$e	Fitness: 5
# Generation: 44	String: I lyve Da&};cien$e	Fitness: 5
# Generation: 45	String: I lyve Da&};cien$e	Fitness: 5
# Generation: 46	String: I lyve DaRJScienne	Fitness: 4
# Generation: 47	String: I lyve DaRJScienne	Fitness: 4
# Generation: 48	String: I lyve DaRJScienne	Fitness: 4
# Generation: 49	String: I lyve DaRJScienne	Fitness: 4
# Generation: 50	String: I lyve DaRJScienne	Fitness: 4
# Generation: 51	String: I lyve DaRJScienne	Fitness: 4
# Generation: 52	String: I lyve DaRJScienne	Fitness: 4
# Generation: 53	String: I love DaXdScien$e	Fitness: 3
# Generation: 54	String: I love DaXdScien$e	Fitness: 3
# Generation: 55	String: I love DaXdScien$e	Fitness: 3
# Generation: 56	String: I love DaXdScien$e	Fitness: 3
# Generation: 57	String: I love DaXdScien$e	Fitness: 3
# Generation: 58	String: I love DaXdScien$e	Fitness: 3
# Generation: 59	String: I love DaXdScien$e	Fitness: 3
# Generation: 60	String: I love DaXdScien$e	Fitness: 3
# Generation: 61	String: I love Da3JScience	Fitness: 2
# Generation: 62	String: I love Da3JScience	Fitness: 2
# Generation: 63	String: I love Da3JScience	Fitness: 2
# Generation: 64	String: I love Da3JScience	Fitness: 2
# Generation: 65	String: I love Da3JScience	Fitness: 2
# Generation: 66	String: I love Da3JScience	Fitness: 2
# Generation: 67	String: I love Da3JScience	Fitness: 2
# Generation: 68	String: I love Da3JScience	Fitness: 2
# Generation: 69	String: I love Da3JScience	Fitness: 2
# Generation: 70	String: I love Da3JScience	Fitness: 2
# Generation: 71	String: I love Da3JScience	Fitness: 2
# Generation: 72	String: I love Da3JScience	Fitness: 2
# Generation: 73	String: I love Da3JScience	Fitness: 2
# Generation: 74	String: I love Da3JScience	Fitness: 2
# Generation: 75	String: I love Da3JScience	Fitness: 2
# Generation: 76	String: I love Da3JScience	Fitness: 2
# Generation: 77	String: I love DatJScience	Fitness: 1
# Generation: 78	String: I love DatJScience	Fitness: 1
# Generation: 79	String: I love DatJScience	Fitness: 1
# Generation: 80	String: I love DatJScience	Fitness: 1
# Generation: 81	String: I love DatJScience	Fitness: 1
# Generation: 82	String: I love DatJScience	Fitness: 1
# Generation: 83	String: I love DatJScience	Fitness: 1
# Generation: 84	String: I love DatJScience	Fitness: 1
# Generation: 85	String: I love DatJScience	Fitness: 1
# Generation: 86	String: I love DatJScience	Fitness: 1
# Generation: 87	String: I love DatJScience	Fitness: 1
# Generation: 88	String: I love DatJScience	Fitness: 1
# Generation: 89	String: I love DatJScience	Fitness: 1
# Generation: 90	String: I love DatJScience	Fitness: 1
# Generation: 91	String: I love DatJScience	Fitness: 1
# Generation: 92	String: I love DatJScience	Fitness: 1
# Generation: 93	String: I love DatJScience	Fitness: 1
